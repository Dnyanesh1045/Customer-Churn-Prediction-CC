# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa  # Facilate connection between Python program and sql database
import seaborn as sns
import missingno
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
sns.set()

# %%
# Make a connection with Database
engine=sa.create_engine("mysql+pymysql://root:system@localhost:3306/db_aug")
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/db_aug)

# %%
df=pd.read_sql_query("select * from bankchurners",engine)
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
pd.set_option("display.max_columns",25)

# %%
df99=pd.read_sql_table("bankchurners",engine)
df99.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.shape
# Out:
# (10127, 21)

# %%
df.sample(4)
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 3323  708665133  Existing Customer            40      M                2
# 9322  716124408  Attrited Customer            32      M                2
# 174   820353558  Existing Customer            41      F                3
# 9808  714145233  Attrited Customer            34      M                0
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 3323        Graduate        Married    $80K - $120K          Blue
# 9322        Graduate         Single         $120K +          Gold
# 174      High School        Married     $40K - $60K          Blue
# 9808        Graduate       Divorced    $80K - $120K        Silver
#
#       Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 3323              28                         6                       2
# 9322              22                         2                       2
# ...

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df.describe(include="all")
# Out:
#            CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# count   1.012700e+04              10127  10127.000000  10127     10127.000000
# unique           NaN                  2           NaN      2              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               8500           NaN   5358              NaN
# mean    7.391776e+08                NaN     46.325960    NaN         2.346203
# std     3.690378e+07                NaN      8.016814    NaN         1.298908
# min     7.080821e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130368e+08                NaN     41.000000    NaN         1.000000
# 50%     7.179264e+08                NaN     46.000000    NaN         2.000000
# 75%     7.731435e+08                NaN     52.000000    NaN         3.000000
# max     8.283431e+08                NaN     73.000000    NaN         5.000000
#
# ...

# %%
# define numerical & categorical columns
numeric_features=[ feature for feature in df.columns if df[feature].dtype !='O' ]
categorical_features = [feature for feature in df.columns if df[feature].dtype=='O']

print("numeric_features:",len(numeric_features))
print("categorical_features:",len(categorical_features))
# Out:
# numeric_features: 15
# categorical_features: 6

# %%
listItem = []
for col in df.columns :
    listItem.append([col,df[col].dtype,df[col].isnull().sum(),
                     round((df[col].isnull().sum()/len(df[col])) * 100,2),
                     df[col].nunique(), list(df[col].drop_duplicates().sample(2).values)])
dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null',
                               'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
dfDesc
# Out:
#                 dataFeatures dataType  null  nullPct  unique  \
# 0                  CLIENTNUM    int64     0      0.0   10127
# 1             Attrition_Flag   object     0      0.0       2
# 2               Customer_Age    int64     0      0.0      45
# 3                     Gender   object     0      0.0       2
# 4            Dependent_count    int64     0      0.0       6
# 5            Education_Level   object     0      0.0       7
# 6             Marital_Status   object     0      0.0       4
# 7            Income_Category   object     0      0.0       6
# 8              Card_Category   object     0      0.0       4
# 9             Months_on_book    int64     0      0.0      44
# 10  Total_Relationship_Count    int64     0      0.0       6
# 11    Months_Inactive_12_mon    int64     0      0.0       7
# 12     Contacts_Count_12_mon    int64     0      0.0       7
# 13              Credit_Limit    int64     0      0.0    6205
# ...

# %%
listItem = []
for col in df.columns:
    listItem.append([col,df[col].dtype,df[col].isnull().sum(),
                    round((df[col].isnull().sum()/len(df[col]))*100,2),
                     df[col].nunique(),list(df[col].drop_duplicates().sample(2).values)])
dfDesc = pd.DataFrame(columns=["Datafeatures","DataType","null",'nullPct','unique','uniqueSample'],data=listItem)
dfDesc
# Out:
#                 Datafeatures DataType  null  nullPct  unique  \
# 0                  CLIENTNUM    int64     0      0.0   10127
# 1             Attrition_Flag   object     0      0.0       2
# 2               Customer_Age    int64     0      0.0      45
# 3                     Gender   object     0      0.0       2
# 4            Dependent_count    int64     0      0.0       6
# 5            Education_Level   object     0      0.0       7
# 6             Marital_Status   object     0      0.0       4
# 7            Income_Category   object     0      0.0       6
# 8              Card_Category   object     0      0.0       4
# 9             Months_on_book    int64     0      0.0      44
# 10  Total_Relationship_Count    int64     0      0.0       6
# 11    Months_Inactive_12_mon    int64     0      0.0       7
# 12     Contacts_Count_12_mon    int64     0      0.0       7
# 13              Credit_Limit    int64     0      0.0    6205
# ...

# %%
df["Attrition_Flag"].value_counts(normalize=True)*100
# Out:
# Existing Customer    83.934038
# Attrited Customer    16.065962
# Name: Attrition_Flag, dtype: float64

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(20,15),facecolor="w")
sns.heatmap(df.corr(),annot=True,cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
#sns.heatmap(df.isnull(),annot=True,cmap="RdYlGn")

# %%
plt.figure(figsize=(15,7))
df["Education_Level"].value_counts().plot(kind="pie",autopct="%f.2")
# Out:
# <AxesSubplot:ylabel='Education_Level'>

# %%
df.hist("Customer_Age")
# Out:
# array([[<AxesSubplot:title={'center':'Customer_Age'}>]], dtype=object)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df["Attrition_Flag"], Customer_Age,edgecolor="black")
plt.title("Customer Existed and Customer Attrated",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
df["Attrition_Flag"].value_counts().plot(kind="pie",autopct="%.2f")
plt.show()

# %% [markdown]
# ### we can see from this plot, customers who choose move to another bank is 16.07%

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df["Attrition_Flag"],hue=df["Gender"],edgecolor = 'black')
plt.title('Customer Existing and Customer Attrated', fontsize=20)

plt.show()

# %% [markdown]
# ## we can see from this plot, Female customers who choose move to  another bank is more compare to male

# %%
plt.figure(figsize=(10,5))
total = float(len(df))
ax = sns.countplot(x=df["Card_Category"], edgecolor = 'black')
plt.title('Credit Card Type', fontsize=20)

plt.show()

# %%
plt.figure(figsize=(10,8))
df["Card_Category"].value_counts().plot(kind="pie",autopct="%.2f")
plt.show()

# %% [markdown]
# ## we can see almost all custumer used blue credit card type

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df["Card_Category"], hue=df["Gender"], edgecolor = 'black')
plt.title('Credit Card Type \n by Gender', fontsize=20)
plt.xlabel('Card Category', fontsize=10)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df["Education_Level"], edgecolor = 'black', order = df["Education_Level"].value_counts().index)
plt.title('Persentage Used Credit by Education', fontsize=15)
plt.xlabel('Education', fontsize = 20)
plt.xticks(size = 13)
plt.show()

# %%
plt.figure(figsize=(10,8))
df["Education_Level"].value_counts().plot(kind="pie",autopct="%.2f")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df["Education_Level"],edgecolor='black',order=df["Education_Level"].value_counts().index)
plt.title("Use of Credit Card",fontsize=15)
plt.xlabel("Education",fontsize=15)
plt.xticks(size=10)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df["Education_Level"], edgecolor = 'black')
plt.title('Persentage Used Credit by Education', fontsize=15)
plt.xlabel('Education', fontsize = 20)
plt.xticks(size = 13)
plt.show()

# %%
# plot to visualize the missing value proportion
missingno.bar(df,color="dodgerblue", sort="ascending", figsize=(10,7), fontsize=12)
plt.show()

# %% [markdown]
# # Visualize the Distribution of all Continuous feature

# %%
print(numeric_features)
# Out:
# ['CLIENTNUM', 'Customer_Age', 'Dependent_count', 'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']

# %%
for col in numeric_features:
    df.hist(col)

# %%
df.hist(bins=50,figsize=(30,20))
plt.show()

# %%
for col in numeric_features:
    sns.displot(df[col])
    plt.title(col)
    plt.show()

# %%
for col in numeric_features:
    sns.displot(df[col],kind="kde")
    plt.title(col)
    plt.show()

# %%
# Distplot
plt.figure(figsize=(20,10))
for col in numeric_features:
    sns.distplot(df[col])
    plt.title(col)
    plt.show()

# %%
print(df.columns)
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
sns.scatterplot(df["Customer_Age"],df["Total_Revolving_Bal"],hue=df["Gender"])
plt.show()
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Total_Revolving_Bal'>

# %%
sns.scatterplot(df["Customer_Age"],df["Avg_Utilization_Ratio"])
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Avg_Utilization_Ratio'>

# %%
sns.scatterplot(df["Customer_Age"],df["Credit_Limit"])
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %%
sns.scatterplot(df["Customer_Age"],df["Card_Category"])
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Card_Category'>

# %%
sns.scatterplot(df["Customer_Age"],df["Education_Level"],df["Attrition_Flag"])
plt.show()

# %%
import missingno
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plot for Outliers Detecton:

# %%
num_feat = df.drop(["CLIENTNUM",
                    "Attrition_Flag",
                    "Gender",
                    "Dependent_count",
                    "Education_Level",
                    "Marital_Status",
                    "Income_Category",
                    "Card_Category"],
                   axis = 1)

# %%
len(num_feat.columns)
# Out:
# 13

# %%
plt.figure(figsize=(60,72))
for i in range(len(num_feat.columns)):
    plt.subplot(7,2,i+1) #  subplot(nrows, ncols, index)
    sns.boxplot(num_feat[num_feat.columns[i]])
    plt.title(num_feat.columns[i],fontsize=36)
    plt.xticks(fontsize=30)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,7))
for i in num_feat.columns:
    sns.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
for i in num_feat.columns:
    sns.boxplot(data=num_feat[i])
    plt.title(i)
    plt.show()

# %%
for i in df:
    print(i)
# Out:
# CLIENTNUM
# Attrition_Flag
# Customer_Age
# Gender
# Dependent_count
# Education_Level
# Marital_Status
# Income_Category
# Card_Category
# Months_on_book
# Total_Relationship_Count
# Months_Inactive_12_mon
# Contacts_Count_12_mon
# Credit_Limit
# Total_Revolving_Bal
# Avg_Open_To_Buy
# Total_Amt_Chng_Q4_Q1
# Total_Trans_Amt
# Total_Trans_Ct
# Total_Ct_Chng_Q4_Q1
# Avg_Utilization_Ratio

# %%
from scipy import stats

# %% [markdown]
# # creating function to generate IQR, lower limit, and Upper limit

# %%
# Creating Function to generate IQR, lower limit and Upper limit
def find_outlier(df,feature):
    print("Outlier"+ feature)
    q1 = df[feature].quantile(0.25)
    q2 = df[feature].quantile(0.50)
    q3 = df[feature].quantile(0.75)
    iqr = q3-q1
    limit = iqr*1.5
    print(f"IQR:{iqr}")
    
    Lower_limit=q1-limit
    if Lower_limit < 0:
        Lower_limit = 0
    upper_limit = q3+limit
    print(f"Lower_limit:{Lower_limit}")
    print(f"median:{q2}")
    print(f"Upper_Limit:{upper_limit}")
    print('______________________________________________')

# %% [markdown]
# # check IQR, upper limit, and lower limit for each feature

# %%
# check IQR, upper limit, and lower limit for each feature

for i in num_feat :
    find_outlier(num_feat, i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 # check IQR, upper limit, and lower limit for each feature
# ----> 3 for i in num_feat :
#       4     find_outlier(num_feat, i)
#
# NameError: name 'num_feat' is not defined

# %%
# creating outliers columns
out1 = df[(df['Customer_Age'] > 68.5) | (df['Customer_Age'] < 24.5)]
out2 = df[(df['Months_on_book'] > 53.5) | (df['Months_on_book'] < 17.5)]
out3 = df[(df['Total_Relationship_Count'] > 8.0) | (df['Total_Relationship_Count'] < 0)]
out4 = df[(df['Months_Inactive_12_mon'] > 4.5) | (df['Months_Inactive_12_mon'] < 0.5)]
out5 = df[(df['Contacts_Count_12_mon'] > 4.5) | (df['Contacts_Count_12_mon'] < 0.5)]
out6 = df[(df['Credit_Limit'] > 23836.25) | (df['Credit_Limit'] < 0)]
out7 = df[(df['Total_Revolving_Bal'] > 3921.5) | (df['Total_Revolving_Bal'] < 0)]
out8 = df[(df['Avg_Open_To_Buy'] > 22660.75) | (df['Avg_Open_To_Buy'] < 0)]
out9 = df[(df['Total_Amt_Chng_Q4_Q1'] > 1.201) | (df['Total_Amt_Chng_Q4_Q1'] < 0.28900000000000003)]
out10 = df[(df['Total_Trans_Amt'] > 8619.25) | (df['Total_Trans_Amt'] < 0)]
out11 = df[(df['Total_Trans_Ct'] > 135.0) | (df['Total_Trans_Ct'] < 0)]
out12 = df[(df['Total_Ct_Chng_Q4_Q1'] > 1.172) | (df['Total_Ct_Chng_Q4_Q1'] < 0.22799999999999998)]
out13 = df[(df['Avg_Utilization_Ratio'] > 1.2229999999999999) | (df['Avg_Utilization_Ratio'] < 0)]

# %%
out1 = df.loc[(df['Customer_Age'] > 68.5) | (df['Customer_Age'] < 24.5)]

# %%
out1

# %%
out100 = df[(df['Customer_Age'] > 68.5) | (df['Customer_Age'] < 24.5)]
out100
# Out:
#      CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 251  715952883  Existing Customer            73      M                0
# 254  787348608  Existing Customer            70      M                0
#
#     Education_Level Marital_Status Income_Category Card_Category  \
# 251     High School        Married     $40K - $60K          Blue
# 254     High School        Married  Less than $40K          Blue
#
#      Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 251              36                         5                       3
# 254              56                         3                       2
#
#      Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 251                      2          4469                 1125
# 254                      3          3252                 1495
#
#      Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# ...

# %%
# creating outliers dataframe
out_all = pd.concat([out1, out2, out3, out4, out5, out6, out7, out8, out9, out10, out11, out12, out13], axis = 0)
out_all.drop_duplicates(inplace=True)
out_all.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # creating outliers dataframe
# ----> 2 out_all = pd.concat([out1, out2, out3, out4, out5, out6, out7, out8, out9, out10, out11, out12, out13], axis = 0)
#       3 out_all.drop_duplicates(inplace=True)
#       4 out_all.head(5)
#
# NameError: name 'out1' is not defined

# %%
# Check outliers percentage

print("Percentage")
len(out_all)/len(df)*100
# Out:
# Percentage
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 4>()
#       1 # Check outliers percentage
#       3 print("Percentage")
# ----> 4 len(out_all)/len(df)*100
#
# NameError: name 'out_all' is not defined

# %%
# we will keep outlier because we asume there is social inequality

# %% [markdown]
# # Check Duplicated Data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()].sum()
# Out:
# CLIENTNUM                   0.0
# Attrition_Flag              0.0
# Customer_Age                0.0
# Gender                      0.0
# Dependent_count             0.0
# Education_Level             0.0
# Marital_Status              0.0
# Income_Category             0.0
# Card_Category               0.0
# Months_on_book              0.0
# Total_Relationship_Count    0.0
# Months_Inactive_12_mon      0.0
# Contacts_Count_12_mon       0.0
# Credit_Limit                0.0
# Total_Revolving_Bal         0.0
# Avg_Open_To_Buy             0.0
# Total_Amt_Chng_Q4_Q1        0.0
# Total_Trans_Amt             0.0
# Total_Trans_Ct              0.0
# Total_Ct_Chng_Q4_Q1         0.0
# Avg_Utilization_Ratio       0.0
# dtype: float64

# %%
# Check Whether there is any duplicate value
pd.DataFrame({"Duplicated Data":df[df.duplicated()].sum()})
# Out:
#                           Duplicated Data
# CLIENTNUM                             0.0
# Attrition_Flag                        0.0
# Customer_Age                          0.0
# Gender                                0.0
# Dependent_count                       0.0
# Education_Level                       0.0
# Marital_Status                        0.0
# Income_Category                       0.0
# Card_Category                         0.0
# Months_on_book                        0.0
# Total_Relationship_Count              0.0
# Months_Inactive_12_mon                0.0
# Contacts_Count_12_mon                 0.0
# Credit_Limit                          0.0
# Total_Revolving_Bal                   0.0
# Avg_Open_To_Buy                       0.0
# Total_Amt_Chng_Q4_Q1                  0.0
# Total_Trans_Amt                       0.0
# Total_Trans_Ct                        0.0
# Total_Ct_Chng_Q4_Q1                   0.0
# Avg_Utilization_Ratio                 0.0

# %% [markdown]
# # Missing Value

# %%
# check missing value
miss = pd.DataFrame({'Missing Value' : df.isnull().sum()})
miss[miss['Missing Value'] > 0 ]
# Out:
# Empty DataFrame
# Columns: [Missing Value]
# Index: []

# %%
missingno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
# this dataset not have duplicated data or missing value

# %% [markdown]
# # Modeling and Evaluation

# %%
# Import Library for Modeling and Evaluations
from sklearn.model_selection import train_test_split,cross_val_score, RandomizedSearchCV
from sklearn.model_selection import GridSearchCV, KFold,StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,GradientBoostingClassifier

import category_encoders as ce
from sklearn.preprocessing import StandardScaler,RobustScaler
from sklearn.compose import  ColumnTransformer
from sklearn.pipeline import Pipeline
from category_encoders import BinaryEncoder
from sklearn.metrics import f1_score,roc_auc_score,roc_curve,accuracy_score,precision_score,recall_score

# %%
# Ordinal Variable
Income_Category_map = {
    'Less than $40K' : 0,
    '$40K - $60K'    : 1,
    '$60K - $80K'    : 2,
    '$80K - $120K'   : 3,
    '$120K +'        : 4,
    'Unknown'        : 5
}

Card_Category_map = {
    'Blue'     : 0,
    'Silver'   : 1,
    'Gold'     : 2,
    'Platinum' : 3
}

Education_Level_map = {
    'Uneducated'    : 0,
    'High School'   : 1,
    'College'       : 2,
    'Graduate'      : 3,
    'Post-Graduate' : 4,
    'Doctorate'     : 5,
    'Unknown'       : 6
}

df.loc[:, 'Income_Category'] = df['Income_Category'].map(Income_Category_map)
df.loc[:, 'Card_Category'] = df['Card_Category'].map(Card_Category_map)
df.loc[:, 'Education_Level'] = df['Education_Level'].map(Education_Level_map)

# Nominal Variable

Gender_map = {
    'M' : 0,
    'F' : 1
}

Attrition_Flag_map = {
    'Existing Customer' : 0,
    'Attrited Customer' : 1
}

Marital_Status_map = {
    'Single' : 0,
    'Married' : 1,
    'Divorced' : 2,
    'Unknown' : 3
}


df.loc[:, 'Gender'] = df['Gender'].map(Gender_map)
df['Dependent_count'].astype(int)
df.loc[:, 'Attrition_Flag'] = df['Attrition_Flag'].map(Attrition_Flag_map)
df.loc[:, 'Marital_Status'] = df['Marital_Status'].map(Marital_Status_map)

# %%
df.head()
# Out:
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               0            45       0                3
# 1  818770008               0            49       1                5
# 2  713982108               0            51       0                3
# 3  769911858               0            40       1                4
# 4  709106358               0            40       0                3
#
#    Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                1               1                2              0
# 1                3               0                0              0
# 2                3               1                3              0
# 3                1               3                0              0
# 4                0               1                2              0
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.shape
# Out:
# (10127, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  int64
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  int64
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  int64
#  6   Marital_Status            10127 non-null  int64
#  7   Income_Category           10127 non-null  int64
#  8   Card_Category             10127 non-null  int64
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  int64
# ...

# %% [markdown]
# # Train Test Split

# %%
X= df.drop(['CLIENTNUM', 'Attrition_Flag'], axis = 1)
y = df['Attrition_Flag']

# %%
df.corr()
# Out:
#                           CLIENTNUM  Attrition_Flag  Customer_Age    Gender  \
# CLIENTNUM                  1.000000       -0.046430      0.007613 -0.020188
# Attrition_Flag            -0.046430        1.000000      0.018203  0.037272
# Customer_Age               0.007613        0.018203      1.000000  0.017312
# Gender                    -0.020188        0.037272      0.017312  1.000000
# Dependent_count            0.006772        0.018991     -0.122254 -0.004563
# Education_Level            0.007143        0.019545      0.004909  0.010527
# Marital_Status             0.016022       -0.005146     -0.022963 -0.015075
# Income_Category            0.005970       -0.003819      0.017724 -0.349665
# Card_Category              0.002086        0.002354     -0.018235 -0.080093
# Months_on_book             0.134588        0.013687      0.788912  0.006728
# Total_Relationship_Count   0.006907       -0.150005     -0.010931 -0.003157
# ...

# %%
plt.figure(figsize=(20,20),facecolor="w")
sns.heatmap(df.corr(),annot=True,cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor
selection=ExtraTreesRegressor()
selection.fit(X,y)

# %%
# Important feature using ExtraTreeRegressor

from sklearn.ensemble import ExtraTreesRegressor
selection=ExtraTreesRegressor()
selection.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.02546891 0.01819083 0.01674597 0.0139807  0.01543074 0.01174476
#  0.00551021 0.01811038 0.09373812 0.03145111 0.03342855 0.01548556
#  0.14415971 0.01565511 0.04647111 0.17374511 0.22169339 0.07171454
#  0.02727519]

# %%
# Plot graph of feature importances for better visualization

plt.figure(figsize=(12,8))
feat_imp=pd.Series(selection.feature_importances_,index=X.columns)
feat_imp.nlargest(20).plot(kind="barh")
plt.show()

# %%
# Plot graph of feature importances for better visualization

plt.figure(figsize=(12,5))
feat_imp=pd.Series(selection.feature_importances_,index=X.columns)
feat_imp.nlargest(20).plot(kind="bar")
plt.show()

# %%
plt.figure(figsize=(15,15))
feat_imp.nlargest(20).plot(kind="pie",autopct="%0.2f")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
feat_imp
# Out:
# Customer_Age                0.025469
# Gender                      0.018191
# Dependent_count             0.016746
# Education_Level             0.013981
# Marital_Status              0.015431
# Income_Category             0.011745
# Card_Category               0.005510
# Months_on_book              0.018110
# Total_Relationship_Count    0.093738
# Months_Inactive_12_mon      0.031451
# Contacts_Count_12_mon       0.033429
# Credit_Limit                0.015486
# Total_Revolving_Bal         0.144160
# Avg_Open_To_Buy             0.015655
# Total_Amt_Chng_Q4_Q1        0.046471
# Total_Trans_Amt             0.173745
# Total_Trans_Ct              0.221693
# Total_Ct_Chng_Q4_Q1         0.071715
# Avg_Utilization_Ratio       0.027275
# dtype: float64

# %%
###############################################################################################

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %%
Xnew=SelectKBest(chi2,k=15)

# %%
Xnew.fit(X,y)
# Out:
# SelectKBest(k=15, score_func=<function chi2 at 0x000001DB554D7790>)

# %%
top_15_feature=Xnew.get_feature_names_out()
print(top_15_feature)
# Out:
# ['Customer_Age' 'Gender' 'Education_Level' 'Months_on_book'
#  'Total_Relationship_Count' 'Months_Inactive_12_mon'
#  'Contacts_Count_12_mon' 'Credit_Limit' 'Total_Revolving_Bal'
#  'Avg_Open_To_Buy' 'Total_Amt_Chng_Q4_Q1' 'Total_Trans_Amt'
#  'Total_Trans_Ct' 'Total_Ct_Chng_Q4_Q1' 'Avg_Utilization_Ratio']

# %%
x=Xnew.transform(X)

# %%
x
# Out:
# array([[4.500e+01, 0.000e+00, 1.000e+00, ..., 4.200e+01, 1.625e+00,
#         6.100e-02],
#        [4.900e+01, 1.000e+00, 3.000e+00, ..., 3.300e+01, 3.714e+00,
#         1.050e-01],
#        [5.100e+01, 0.000e+00, 3.000e+00, ..., 2.000e+01, 2.333e+00,
#         0.000e+00],
#        ...,
#        [4.400e+01, 1.000e+00, 1.000e+00, ..., 6.000e+01, 8.180e-01,
#         0.000e+00],
#        [3.000e+01, 0.000e+00, 3.000e+00, ..., 6.200e+01, 7.220e-01,
#         0.000e+00],
#        [4.300e+01, 1.000e+00, 3.000e+00, ..., 6.100e+01, 6.490e-01,
#         1.890e-01]])

# %%
x_15=pd.DataFrame(x,columns=top_15_feature)
x_15
# Out:
#        Customer_Age  Gender  Education_Level  Months_on_book  \
# 0              45.0     0.0              1.0            39.0
# 1              49.0     1.0              3.0            44.0
# 2              51.0     0.0              3.0            36.0
# 3              40.0     1.0              1.0            34.0
# 4              40.0     0.0              0.0            21.0
# ...             ...     ...              ...             ...
# 10122          50.0     0.0              3.0            40.0
# 10123          41.0     0.0              6.0            25.0
# 10124          44.0     1.0              1.0            36.0
# 10125          30.0     0.0              3.0            36.0
# 10126          43.0     1.0              3.0            25.0
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                           5.0                     1.0
# 1                           6.0                     1.0
# 2                           4.0                     1.0
# ...

# %%
x_15.shape
# Out:
# (10127, 15)

# %%
x_15.columns
# Out:
# Index(['Customer_Age', 'Gender', 'Education_Level', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
##########################################################################################

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=2023)
X_train=X_train.reset_index(drop=True)
X_test=X_test.reset_index(drop=True)

# %%
st_scaler=StandardScaler()
rb_scaler=RobustScaler()

transformer = ColumnTransformer([
    ("standard scaler",st_scaler,['Customer_Age', 'Months_on_book', 'Total_Revolving_Bal', 
                                             'Total_Amt_Chng_Q4_Q1', 'Total_Ct_Chng_Q4_Q1', 'Total_Trans_Ct']),
    ("robust scaler",rb_scaler,['Credit_Limit', 'Avg_Open_To_Buy', 
                                             'Total_Trans_Amt', 'Avg_Utilization_Ratio'])
],remainder = "passthrough")

# %%
# We use robust scaler cause dataset have many outlier

# %%
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('standard scaler', StandardScaler(),
#                                  ['Customer_Age', 'Months_on_book',
#                                   'Total_Revolving_Bal', 'Total_Amt_Chng_Q4_Q1',
#                                   'Total_Ct_Chng_Q4_Q1', 'Total_Trans_Ct']),
#                                 ('robust scaler', RobustScaler(),
#                                  ['Credit_Limit', 'Avg_Open_To_Buy',
#                                   'Total_Trans_Amt',
#                                   'Avg_Utilization_Ratio'])])

# %%
df.head()
# Out:
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               0            45       0                3
# 1  818770008               0            49       1                5
# 2  713982108               0            51       0                3
# 3  769911858               0            40       1                4
# 4  709106358               0            40       0                3
#
#    Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                1               1                2              0
# 1                3               0                0              0
# 2                3               1                3              0
# 3                1               3                0              0
# 4                0               1                2              0
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %% [markdown]
# # Modeling

# %%
logreg = LogisticRegression(random_state=2023)
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier(random_state=2023)
rf = RandomForestClassifier(random_state=2023)
ab = AdaBoostClassifier(random_state=2023)
gb = GradientBoostingClassifier(random_state=2023)

# %%
list_model = {'Logistic Regression' : logreg, 'KNN' : knn, 'Decision Tree' : dt, 'Random Forest' : rf, 
              'AdaBoost' :ab, 'GradientBoost' : gb}

# %%
model_list = [logreg,knn,dt,rf,ab,gb]

# %%
f1_score = []
mean_f1_score = []
std_f1_score = []
crossval = StratifiedKFold(n_splits=5)

def model_eval_f1_score(model):  # Pass Dictionary of models
    for i in model:
        estimator = Pipeline([
            ('tranformer',transformer),
            ('model',list_model[i])
        ])
        model_cv=cross_val_score(estimator,X_train,y_train,cv=crossval,scoring='f1',error_score='raise')
        f1_score.append(model_cv)
        mean_f1_score.append(model_cv.mean())
        std_f1_score.append(model_cv.std())

# %%
roc_auc = []
mean_roc_auc = []
std_roc_auc = []
crossval = StratifiedKFold(n_splits=5)

def model_eval_roc_auc(model): # Pass Dictionary of models
    for i in model:
        estimator = Pipeline([
            ('tranformer',transformer),
            ('model',list_model[i])
        ])
        model_cv=cross_val_score(estimator,X_train,y_train,cv=crossval,scoring='roc_auc',error_score='raise')
        roc_auc.append(model_cv)
        mean_roc_auc.append(model_cv.mean())
        std_roc_auc.append(model_cv.std())

# %%
model_eval_f1_score(list_model)  # # Pass Dictionary of models

# %%
model_eval_roc_auc(list_model)    # Pass Dictionary of models

# %%
model_b_tuning = pd.DataFrame({'model':['Logistic Regression', 'KNN', 'Decision Tree', 'Random Forest', 'AdaBoost', 'GradientBoost'],
    'f1_Score' : f1_score,
    'f1_score_Mean':mean_f1_score,
    'f1_score_std':std_f1_score,
    'roc_auc' : roc_auc,
    'roc_auc_Mean': mean_roc_auc,
    'roc_auc_Std': std_roc_auc
})

model_b_tuning
# Out:
#                  model                                           f1_Score  \
# 0  Logistic Regression  [0.6683673469387755, 0.6284289276807979, 0.646...
# 1                  KNN  [0.6528497409326425, 0.5865921787709498, 0.634...
# 2        Decision Tree  [0.8222698072805138, 0.7863636363636364, 0.797...
# 3        Random Forest  [0.8770301624129931, 0.8502415458937198, 0.893...
# 4             AdaBoost  [0.8819599109131403, 0.8564814814814816, 0.884...
# 5        GradientBoost  [0.8807339449541285, 0.8738317757009346, 0.911...
#
#    f1_score_Mean  f1_score_std  \
# 0       0.649044      0.016218
# 1       0.627640      0.022852
# 2       0.793383      0.020004
# 3       0.864879      0.017846
# 4       0.861103      0.020019
# 5       0.883027      0.014300
#
#                                              roc_auc  roc_auc_Mean  \
# 0  [0.9353866042801371, 0.907444882309085, 0.9170...      0.920903
# 1  [0.9086091207245455, 0.8693298467392142, 0.897...      0.887269
# ...

# %%
recall = []
recall_mean = []
std_recall = []
crossval = StratifiedKFold(n_splits=5)

def model_eval_recall(model): # Pass Dictionary of models
    for i in model:
        estimator = Pipeline([
            ('tranformer',transformer),
            ('model',list_model[i])
        ])
        model_cv=cross_val_score(estimator,X_train,y_train,cv=crossval,scoring='recall',error_score='raise')
        recall.append(model_cv)
        recall_mean.append(model_cv.mean())
        std_recall.append(model_cv.std())

# %%
recall_df = pd.DataFrame({'model':['Logistic Regression', 'KNN', 'Decision Tree', 'Random Forest', 'AdaBoost', 'GradientBoost'],
    'recall' : f1_score,
    'recall_mean':mean_f1_score,
    'std_recall':std_f1_score,
})

recall_df
# Out:
#                  model                                             recall  \
# 0  Logistic Regression  [0.6683673469387755, 0.6284289276807979, 0.646...
# 1                  KNN  [0.6528497409326425, 0.5865921787709498, 0.634...
# 2        Decision Tree  [0.8222698072805138, 0.7863636363636364, 0.797...
# 3        Random Forest  [0.8770301624129931, 0.8502415458937198, 0.893...
# 4             AdaBoost  [0.8819599109131403, 0.8564814814814816, 0.884...
# 5        GradientBoost  [0.8807339449541285, 0.8738317757009346, 0.911...
#
#    recall_mean  std_recall
# 0     0.649044    0.016218
# 1     0.627640    0.022852
# 2     0.793383    0.020004
# 3     0.864879    0.017846
# 4     0.861103    0.020019
# 5     0.883027    0.014300

# %% [markdown]
# ## Hyperparameter Tuning
#
#
# * Choose following method for hyperparameter tuning
#     1. **RandomizedSearchCV** --> Fast
#     2. **GridSearchCV**
# * Assign hyperparameters in form of dictionery
# * Fit the model
# * Check best paramters and best score

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Randomized search CV

# Number of trees in Random Forest
n_estimators = [int(x) for x in np.linspace(start=100,stop=1200,num=12)]

# Number of feature to consider at every split
max_features=['auto','sqrt']

# Maximum depth of trees
max_depth= [int(x) for x in np.linspace(5,30,num=6)]

# Minimum number of sample required to split a node
min_samples_split = [2,5,10,15,100]

# Minimum number of sample required at each node
min_sample_leaf = [1,2,3,4,10]

# %%
# Create the random grid

random_grid={"n_estimators":n_estimators,
             "max_features":max_features,
             "max_depth":max_depth,
             "min_samples_split":min_samples_split,
             "min_samples_leaf":min_sample_leaf
            }

# %%
# Random search of Parameters, using 5 fold cross validation,
# Search across 100 different combinations
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring="neg_mean_squared_error",n_iter=10,cv=5,verbose=2,random_state=42,n_jobs=1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=3, min_samples_split=100, n_estimators=700; total time=   7.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=3, min_samples_split=100, n_estimators=700; total time=   7.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=3, min_samples_split=100, n_estimators=700; total time=   7.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=3, min_samples_split=100, n_estimators=700; total time=   7.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=3, min_samples_split=100, n_estimators=700; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   4.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   4.1s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 900,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 30}

# %%
rf_random.best_score_
# Out:
# -0.04275018339665536

# %%
prediction = rf_random.predict(X_test)

# %%
accuracy_score(y_test,rf_random.predict(X_test))
# Out:
# 0.9559065482066469

# %%
recall_score(y_test,rf_random.predict(X_test))
# Out:
# 0.8029045643153527

# %%
# We selected Random forest mOdel Which has Good Accuracy:
# Make pickle to Use it again

# %%
import pickle

file=open("random_forest.pkl","wb")
pickle.dump(rf_random,file)

# %%
# model = pickle.load(open('best_RF_model.pkl','rb'))
# model.predict(testdata)
